# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import cv2
import os
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
# Get File Paths and Labels ---
BATCH_SIZE = 32 
CATEGORIES = ['Cardboard', 'Food Organics', 'Glass', 'Metal', 'Miscellaneous Trash', 'Paper', 'Plastic', 'Textile Trash']
labels_map = {cat: index for index, cat in enumerate(CATEGORIES)} 

all_image_filepaths = []
all_image_labels = []

basefolder = "RealWaste/" 

for index, cat_name in enumerate(CATEGORIES):
    sub_directory = os.path.join(basefolder, cat_name)
    if not os.path.isdir(sub_directory):
        print(f"Warning: Directory '{sub_directory}' for category '{cat_name}' not found. Skipping.")
        continue
    
    try:
        image_filenames = os.listdir(sub_directory)
        for image_filename in image_filenames:
            if image_filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                full_image_path = os.path.join(sub_directory, image_filename)
                all_image_filepaths.append(full_image_path)
                all_image_labels.append(labels_map[cat_name])

    except OSError as e:
        print(f"Error listing files in '{sub_directory}': {e}. Skipping.")

# Convert to NumPy arrays for easier handling with train_test_split
all_image_filepaths = np.array(all_image_filepaths)
all_image_labels = np.array(all_image_labels)

print(f"Total image paths found: {len(all_image_filepaths)}")
print(f"Total labels found: {len(all_image_labels)}")
# Out:
# Total image paths found: 4316
# Total labels found: 4316

# %%
# Split into training (60%), validation (20%), and test (20%)
X_train_paths, X_temp_paths, Y_train, Y_temp_labels = train_test_split(
    all_image_filepaths,
    all_image_labels,
    test_size=0.4,  # Reserve 40% for validation + test baad mai usko bhi split karein gay
    random_state=42,
    stratify=all_image_labels
)

X_val_paths, X_test_paths, Y_val, Y_test = train_test_split(
    X_temp_paths,
    Y_temp_labels,
    test_size=0.5,  # Splitting the 40% into 20% validation and 20% test
    random_state=42,
    stratify=Y_temp_labels
)

print(f"Training paths: {len(X_train_paths)}, Training labels: {len(Y_train)}")
print(f"Validation paths: {len(X_val_paths)}, Validation labels: {len(Y_val)}")
print(f"Test paths: {len(X_test_paths)}, Test labels: {len(Y_test)}")
# Out:
# Training paths: 2589, Training labels: 2589
# Validation paths: 863, Validation labels: 863
# Test paths: 864, Test labels: 864

# %%
import random 

def preprocess_and_augment_image(image_path, augment=False):

    # Load image
    image_bgr = cv2.imread(image_path)

    if image_bgr is None:
        print(f"Warning: Could not read image {image_path}. Returning None.")
        return None # Handle this in the generator

    # Preprocessing Steps
    # BGR to RGB
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

    # Resize
    target_height = 256
    target_width = 256
    image_resized = cv2.resize(image_rgb, (target_width, target_height), interpolation=cv2.INTER_AREA)

    # Noise Reduction (Bilateral Filter)
    image_denoised = cv2.bilateralFilter(image_resized, d=7, sigmaColor=50, sigmaSpace=50)

    # DATA AUGMENTATION 
    if augment:
        # Random Horizontal Flip
        if random.random() > 0.5:
            image_denoised = cv2.flip(image_denoised, 1)

        # Random Rotation (simple, might need padding for black corners)
        if random.random() > 0.5:
            angle = random.uniform(-15, 15)
            rows, cols, _ = image_denoised.shape
            M = cv2.getRotationMatrix2D((cols/2, rows/2), angle, 1)
            image_denoised = cv2.warpAffine(image_denoised, M, (cols, rows))
        
        # Random Brightness/Contrast
        if random.random() > 0.5:
            alpha = random.uniform(0.7, 1.3) # Contrast
            beta = random.randint(-30, 30)   # Brightness
            image_denoised = cv2.convertScaleAbs(image_denoised, alpha=alpha, beta=beta)

            # Ensure it's still uint8 [0,255] after this for CLAHE if CLAHE needs it
            image_denoised = np.clip(image_denoised, 0, 255).astype(np.uint8)


    # Contrast Enhancement (CLAHE) - applied after augmentation
    image_lab = cv2.cvtColor(image_denoised, cv2.COLOR_RGB2LAB)
    l_channel, a_channel, b_channel = cv2.split(image_lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(9,9))
    clahe_l_channel = clahe.apply(l_channel)
    clahe_image_lab_merged = cv2.merge((clahe_l_channel, a_channel, b_channel))
    image_after_clahe_rgb = cv2.cvtColor(clahe_image_lab_merged, cv2.COLOR_LAB2RGB)

    # Normalization
    image_normalized = image_after_clahe_rgb.astype(np.float32) / 255.0
    
    return image_normalized

# %%
def data_generator(filepaths, labels, batch_size, augment=False):
    num_samples = len(filepaths)
    
    while True: 
        indices = np.arange(num_samples)
        if augment: # Shuffle training data each epoch
            np.random.shuffle(indices)

        for offset in range(0, num_samples, batch_size):
            batch_indices = indices[offset : offset + batch_size]
            
            batch_x_paths = filepaths[batch_indices]
            batch_y = labels[batch_indices]

            batch_x_images = []
            for path in batch_x_paths:
                processed_image = preprocess_and_augment_image(path, augment=augment)
                if processed_image is not None: 
                    batch_x_images.append(processed_image)

            # Only yield if the batch has a consistent number of images and labels
            if len(batch_x_images) == len(batch_y) and len(batch_x_images) > 0 :
                 yield np.array(batch_x_images), np.array(batch_y)
            elif len(batch_x_images) == 0 and len(batch_x_paths) > 0:
                print(f"Warning: A batch was skipped because all images in it failed to load/process.")

# %%
NUM_CLASSES = 8
IMG_HEIGHT = 256
IMG_WIDTH = 256

model_light = tf.keras.Sequential([
    layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same',
                  input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(units=64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(units=NUM_CLASSES, activation='softmax')
])

model_light.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model_light.summary()
# Out:
# c:\Users\Inshal Munaf\VsCodeProjects\Waste_Classification\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     4,194,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,218,472 (16.09 MB)
#  Trainable params: 4,218,472 (16.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
BATCH_SIZE = 32 

train_gen = data_generator(X_train_paths, Y_train, BATCH_SIZE, augment=True)
val_gen = data_generator(X_val_paths, Y_val, BATCH_SIZE, augment=False) 

# Added Callbacks for better training
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint('best_waste_model.keras', monitor='val_loss', save_best_only=True, verbose=1)


print("Starting model training with generators...")
history = model_light.fit(
    train_gen,
    steps_per_epoch=len(X_train_paths) // BATCH_SIZE, 
    epochs=50,  
    validation_data=val_gen,
    validation_steps=len(X_val_paths) // BATCH_SIZE, 
    callbacks=[early_stopping, model_checkpoint]
)

print("Training finished.")

#  Plotting training history 
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1) 
plt.title("Model Training History")
plt.show()
# Out:
# Starting model training with generators...
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.1721 - loss: 2.3041
# Epoch 1: val_loss improved from inf to 2.03219, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.1724 - loss: 2.3017 - val_accuracy: 0.1899 - val_loss: 2.0322
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.1906 - loss: 2.0259
# Epoch 2: val_loss improved from 2.03219 to 1.93467, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 77s 969ms/step - accuracy: 0.1909 - loss: 2.0256 - val_accuracy: 0.2945 - val_loss: 1.9347
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.2513 - loss: 1.9635
# Epoch 3: val_loss improved from 1.93467 to 1.82877, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 78s 982ms/step - accuracy: 0.2515 - loss: 1.9633 - val_accuracy: 0.3221 - val_loss: 1.8288
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - accuracy: 0.2926 - loss: 1.8488
# Epoch 4: val_loss improved from 1.82877 to 1.74435, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 77s 970ms/step - accuracy: 0.2926 - loss: 1.8486 - val_accuracy: 0.3285 - val_loss: 1.7444
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.3070 - loss: 1.7873
# Epoch 5: val_loss improved from 1.74435 to 1.65790, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 73s 917ms/step - accuracy: 0.3071 - loss: 1.7872 - val_accuracy: 0.3466 - val_loss: 1.6579
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - accuracy: 0.3188 - loss: 1.7351
# Epoch 6: val_loss improved from 1.65790 to 1.60696, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 74s 935ms/step - accuracy: 0.3188 - loss: 1.7353 - val_accuracy: 0.3863 - val_loss: 1.6070
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3118 - loss: 1.7455
# Epoch 7: val_loss did not improve from 1.60696
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.3118 - loss: 1.7453 - val_accuracy: 0.3658 - val_loss: 1.6319
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3139 - loss: 1.6986
# Epoch 8: val_loss improved from 1.60696 to 1.56003, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.3141 - loss: 1.6985 - val_accuracy: 0.4332 - val_loss: 1.5600
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3541 - loss: 1.6501
# Epoch 9: val_loss did not improve from 1.56003
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.3541 - loss: 1.6501 - val_accuracy: 0.4272 - val_loss: 1.5610
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3689 - loss: 1.6283
# Epoch 10: val_loss improved from 1.56003 to 1.44927, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.3690 - loss: 1.6281 - val_accuracy: 0.4994 - val_loss: 1.4493
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4034 - loss: 1.5600
# Epoch 11: val_loss improved from 1.44927 to 1.41887, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.4034 - loss: 1.5598 - val_accuracy: 0.4753 - val_loss: 1.4189
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4091 - loss: 1.5467
# Epoch 12: val_loss did not improve from 1.41887
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.4092 - loss: 1.5467 - val_accuracy: 0.4669 - val_loss: 1.4465
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4069 - loss: 1.5486
# Epoch 13: val_loss did not improve from 1.41887
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.4068 - loss: 1.5486 - val_accuracy: 0.4741 - val_loss: 1.4831
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4380 - loss: 1.4885
# Epoch 14: val_loss did not improve from 1.41887
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.4379 - loss: 1.4886 - val_accuracy: 0.4765 - val_loss: 1.4894
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4366 - loss: 1.4978
# Epoch 15: val_loss improved from 1.41887 to 1.39529, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.4365 - loss: 1.4978 - val_accuracy: 0.4573 - val_loss: 1.3953
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4243 - loss: 1.5243
# Epoch 16: val_loss improved from 1.39529 to 1.33563, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.4244 - loss: 1.5237 - val_accuracy: 0.4886 - val_loss: 1.3356
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4550 - loss: 1.4625
# Epoch 17: val_loss did not improve from 1.33563
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.4550 - loss: 1.4622 - val_accuracy: 0.5307 - val_loss: 1.3432
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4394 - loss: 1.4175
# Epoch 18: val_loss did not improve from 1.33563
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.4396 - loss: 1.4175 - val_accuracy: 0.5150 - val_loss: 1.3632
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4377 - loss: 1.4328
# Epoch 19: val_loss improved from 1.33563 to 1.33214, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.4379 - loss: 1.4325 - val_accuracy: 0.5271 - val_loss: 1.3321
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4777 - loss: 1.3677
# Epoch 20: val_loss improved from 1.33214 to 1.26271, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.4778 - loss: 1.3677 - val_accuracy: 0.5331 - val_loss: 1.2627
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4945 - loss: 1.3078
# Epoch 21: val_loss did not improve from 1.26271
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.4945 - loss: 1.3080 - val_accuracy: 0.5355 - val_loss: 1.3333
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4856 - loss: 1.3603
# Epoch 22: val_loss did not improve from 1.26271
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.4856 - loss: 1.3600 - val_accuracy: 0.5138 - val_loss: 1.3023
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5043 - loss: 1.2852
# Epoch 23: val_loss did not improve from 1.26271
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.5043 - loss: 1.2852 - val_accuracy: 0.5451 - val_loss: 1.2763
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4841 - loss: 1.3636
# Epoch 24: val_loss improved from 1.26271 to 1.25537, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.4843 - loss: 1.3631 - val_accuracy: 0.5259 - val_loss: 1.2554
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4997 - loss: 1.2667
# Epoch 25: val_loss improved from 1.25537 to 1.20617, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5000 - loss: 1.2663 - val_accuracy: 0.5451 - val_loss: 1.2062
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5390 - loss: 1.2158
# Epoch 26: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.5388 - loss: 1.2158 - val_accuracy: 0.5620 - val_loss: 1.2408
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5143 - loss: 1.2650
# Epoch 27: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.5145 - loss: 1.2646 - val_accuracy: 0.5668 - val_loss: 1.2308
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5378 - loss: 1.2316
# Epoch 28: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.5377 - loss: 1.2313 - val_accuracy: 0.5553 - val_loss: 1.2150
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5212 - loss: 1.2147
# Epoch 29: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - accuracy: 0.5213 - loss: 1.2146 - val_accuracy: 0.5517 - val_loss: 1.3735
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5345 - loss: 1.2038
# Epoch 30: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.5344 - loss: 1.2039 - val_accuracy: 0.5276 - val_loss: 1.2334
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5588 - loss: 1.1399
# Epoch 31: val_loss did not improve from 1.20617
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5588 - loss: 1.1399 - val_accuracy: 0.5608 - val_loss: 1.2488
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5760 - loss: 1.1079
# Epoch 32: val_loss improved from 1.20617 to 1.17947, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.5761 - loss: 1.1082 - val_accuracy: 0.5740 - val_loss: 1.1795
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5560 - loss: 1.1131
# Epoch 33: val_loss did not improve from 1.17947
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.5561 - loss: 1.1131 - val_accuracy: 0.5680 - val_loss: 1.2142
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.5815 - loss: 1.0842
# Epoch 34: val_loss improved from 1.17947 to 1.17834, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 71s 890ms/step - accuracy: 0.5815 - loss: 1.0842 - val_accuracy: 0.5824 - val_loss: 1.1783
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.5828 - loss: 1.0444
# Epoch 35: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 68s 858ms/step - accuracy: 0.5828 - loss: 1.0445 - val_accuracy: 0.4970 - val_loss: 1.5109
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.5584 - loss: 1.1361
# Epoch 36: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 862ms/step - accuracy: 0.5585 - loss: 1.1357 - val_accuracy: 0.5752 - val_loss: 1.1866
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.5842 - loss: 1.0759
# Epoch 37: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 68s 859ms/step - accuracy: 0.5843 - loss: 1.0757 - val_accuracy: 0.5752 - val_loss: 1.2171
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.5893 - loss: 1.0747
# Epoch 38: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 864ms/step - accuracy: 0.5894 - loss: 1.0744 - val_accuracy: 0.5680 - val_loss: 1.2216
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.6040 - loss: 1.0443
# Epoch 39: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 865ms/step - accuracy: 0.6041 - loss: 1.0441 - val_accuracy: 0.5921 - val_loss: 1.1863
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.6140 - loss: 1.0074
# Epoch 40: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 863ms/step - accuracy: 0.6140 - loss: 1.0074 - val_accuracy: 0.5921 - val_loss: 1.1851
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.6300 - loss: 0.9794
# Epoch 41: val_loss did not improve from 1.17834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 68s 858ms/step - accuracy: 0.6299 - loss: 0.9793 - val_accuracy: 0.5993 - val_loss: 1.1828
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.6219 - loss: 0.9500
# Epoch 42: val_loss improved from 1.17834 to 1.16814, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 872ms/step - accuracy: 0.6220 - loss: 0.9500 - val_accuracy: 0.6053 - val_loss: 1.1681
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.6310 - loss: 0.9283
# Epoch 43: val_loss did not improve from 1.16814
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 71s 896ms/step - accuracy: 0.6310 - loss: 0.9282 - val_accuracy: 0.5824 - val_loss: 1.2326
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.6167 - loss: 0.9604
# Epoch 44: val_loss did not improve from 1.16814
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 866ms/step - accuracy: 0.6168 - loss: 0.9601 - val_accuracy: 0.5909 - val_loss: 1.1987
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 660ms/step - accuracy: 0.6403 - loss: 0.9403
# Epoch 45: val_loss did not improve from 1.16814
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 68s 857ms/step - accuracy: 0.6404 - loss: 0.9397 - val_accuracy: 0.5921 - val_loss: 1.1975
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.6696 - loss: 0.8555
# Epoch 46: val_loss improved from 1.16814 to 1.15759, saving model to best_waste_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 873ms/step - accuracy: 0.6694 - loss: 0.8557 - val_accuracy: 0.5800 - val_loss: 1.1576
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.6465 - loss: 0.9072
# Epoch 47: val_loss did not improve from 1.15759
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 70s 883ms/step - accuracy: 0.6464 - loss: 0.9072 - val_accuracy: 0.6173 - val_loss: 1.1660
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.6650 - loss: 0.8571
# Epoch 48: val_loss did not improve from 1.15759
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 70s 877ms/step - accuracy: 0.6648 - loss: 0.8575 - val_accuracy: 0.6077 - val_loss: 1.3614
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.6166 - loss: 0.9296
# Epoch 49: val_loss did not improve from 1.15759
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 69s 864ms/step - accuracy: 0.6167 - loss: 0.9295 - val_accuracy: 0.5836 - val_loss: 1.3006
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.6520 - loss: 0.8915
# Epoch 50: val_loss did not improve from 1.15759
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 68s 860ms/step - accuracy: 0.6522 - loss: 0.8910 - val_accuracy: 0.5632 - val_loss: 1.5358
# Restoring model weights from the end of the best epoch: 46.
# Training finished.

# %%
# model_light.save('final_waste_model.keras')

# %%
model_path = 'best_waste_model.keras' 
try:
    loaded_model = tf.keras.models.load_model(model_path)
    print("Model loaded successfully.")
    loaded_model.summary()
except Exception as e:
    print(f"Error loading model: {e}")
    loaded_model = None
# Out:
# Model loaded successfully.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     4,194,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,655,418 (48.28 MB)
#  Trainable params: 4,218,472 (16.09 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8,436,946 (32.18 MB)

# %%
testing_data = data_generator(X_test_paths,Y_test , 32 , augment=False)

# %%
# this function will extract the image path & true Label from the datset    
def extract_image(image_index):
    testing_image_path = X_test_paths[image_index]
    testing_true_label = Y_test[image_index]

    print(f"Testing with image: {testing_image_path}")
    print(f"Its true label (integer): {testing_true_label}")
    
    return testing_image_path,testing_true_label

# %%
def prediction_single_image(testing_image_path , testing_true_label,loaded_model):
    testing_single_image = preprocess_and_augment_image(testing_image_path, augment=False)

    if testing_single_image is not None:

        # visualize the image
        plt.figure(figsize=(5,5))
        plt.imshow(testing_single_image)
        plt.show()

        #making an image a batch of 1 as (1, height, width, channels) this is synxtax that model expects
        testing_image_batch = np.expand_dims(testing_single_image, axis=0)

        # Making a prediction
        prediction_prob = loaded_model.predict(testing_image_batch)
        predicted_class_index = np.argmax(prediction_prob, axis=1)[0]
        predicted_category_name = [name for name, index in labels_map.items() if index == predicted_class_index][0]

        print(f"Predicted class index: {predicted_class_index}")
        print(f"Predicted category: {predicted_category_name}")
        print(f"True Label index : {testing_true_label}")

    else:
        print(f"Failed to process image: {testing_image_path}")

# %%
testing_image_path,testing_true_label= extract_image(1)
prediction_single_image(testing_image_path,testing_true_label,loaded_model)
# Out:
# Testing with image: RealWaste/Miscellaneous Trash\Miscellaneous Trash_122.jpg
# Its true label (integer): 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# Predicted class index: 4
# Predicted category: Miscellaneous Trash
# True Label index : 4

# %%
def evaluate_keras_model(model, model_name, test_filepaths, true_test_labels, data_gen_func, batch_size, categories):

    print(f"\n--- Evaluating Keras Model: {model_name} ---")

    #Create the test data generator
    test_generator = data_gen_func(test_filepaths, true_test_labels, batch_size, augment=False)

    num_testsamples = len(test_filepaths)
    steps_for_evaluation = int(np.ceil(num_testsamples / batch_size))

    print(f"Number of test samples: {num_testsamples}, Steps: {steps_for_evaluation}")

    #Get overall loss and accuracy from model.evaluate()
    evaluation_results = model.evaluate(
        test_generator,
        steps=steps_for_evaluation,
        verbose=1
    )
    test_loss = evaluation_results[0]
    test_accuracy_from_evaluate = evaluation_results[1] 
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy (from model.evaluate): {test_accuracy_from_evaluate*100:.2f}%")

    #Get predictions for detailed metrics

    test_generator_for_predict = data_gen_func(test_filepaths, true_test_labels, batch_size, augment=False)
    #predicting the model
    y_pred_probabilities = model.predict(
        test_generator_for_predict,
        steps=steps_for_evaluation,
        verbose=1
    )
    y_pred_classes = np.argmax(y_pred_probabilities, axis=1)

    #Prepar true labels for comparison
    y_true_for_report = true_test_labels[:len(y_pred_classes)]
    
    if len(y_true_for_report) != len(y_pred_classes):
        print("Detailed metrics might be inaccurate since labels lenght not match'.")
    else:
        # Generate and print Classification Report
        print(f"\nClassification Report for {model_name}:")
        report = classification_report(
            y_true_for_report,
            y_pred_classes,
            target_names=categories,
            zero_division=0
        )
        print(report)

        # Compute and display the Confusion Matrix
        cm = confusion_matrix(y_true_for_report, y_pred_classes)
        plt.figure(figsize=(8, 8))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=categories, yticklabels=categories)
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.title(f'Confusion Matrix - {model_name}')
        plt.xticks(rotation=45, ha='right')
        plt.yticks(rotation=0)
        plt.tight_layout()
        plt.show()


evaluate_keras_model(loaded_model,"CNN Model" ,X_test_paths,Y_test,data_generator,BATCH_SIZE,CATEGORIES)
# Out:
# --- Evaluating Keras Model: CNN Model ---
# Number of test samples: 864, Steps: 27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6209 - loss: 1.1145
# Test Loss: 1.0737
# Test Accuracy (from model.evaluate): 63.08%
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step
#
# Classification Report for CNN Model:
#                      precision    recall  f1-score   support
#
#           Cardboard       0.65      0.85      0.74        93
#       Food Organics       0.80      0.85      0.82        82
#               Glass       0.80      0.65      0.72        84
#               Metal       0.71      0.44      0.54       158
# Miscellaneous Trash       0.45      0.45      0.45        99
#               Paper       0.67      0.60      0.63       100
#             Plastic       0.56      0.83      0.67       185
#       Textile Trash       0.50      0.21      0.29        63
#
#            accuracy                           0.63       864
#           macro avg       0.64      0.61      0.61       864
#        weighted avg       0.64      0.63      0.62       864
